# %% [markdown]
# ### TEST DATA 1 | De - Bugging & Termination | Threshold Development

# %% [markdown]
# ### TERMINATION CRITERION
#
# For this K - Means Model the termination | threshold value is reached when the iterations do not generate new centroids ie. the centroids do not change from the previous iteration.
#
# Having issue's developing the criterion. Pre - empting the use of some sort of loop that intiates the stopping criterion.
#
# An important feature to remember with Python is that when we assign a variable with a value we can later over-write that variable with a future differing value ! This an important component of developing this algorithim that can instigate bugs within the code !
#
# ### TEST DATA 1
#
# elements : 100
#
# max range : 1000
#
# Randomly Assigned Centroids
#
# C1 : 100,150
#
# C2 : 850,900

# %%
#import required libraries
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from math import sqrt

# %%
print('Please input the number of elements required :')
n1 = input()
#convert string to integer rationale range function & randinint requires interger value
n1 = int(n1)
print('Please input the max range :')
n2 = input()
n2 = int(n2)

#create two random lists to hold X & Y co - ordinates of elements
#X co-ordinates
X = []
#Y co - ordinates
Y = []

#intialize for loop with the range function (start/end)
for i in range(0,n1):
    #Generates a random number between a given positive range
    x = random.randint(1,n2)
    #appends to empty list(adds)
    X.append(x)
for i in range(0,n1):
    y = random.randint(1,n2)
    Y.append(y)

#Initiate Centroid 1
print('Please enter centroid 1 co - ordinates')
print('Enter x co - ordinate')
cx1 = input()
cx1 = int(cx1)
print('Enter y co - ordinate')
cy1 = input()
cy1 = int(cy1)
print('Randomly Assigned Centroid1 :',cx1,cy1)

#Initiate Centroid 2
print('Please enter centroid 2 co - ordinates')
print('Enter x co - ordinate')
cx2 = input()
cx2 = int(cx2)
print('Enter y co - ordinate')
cy2 = input()
cy2 = int(cy2)
print('Randomly Assigned Centroid2 :',cx2,cy2)


#SCATTERPLOT 
#x & y co-ordniates
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.scatter(X, Y)
# add centroid 1 & centroid 2
plt.scatter(x=[cx1], y=[cy1], color='b')
plt.scatter(x=[cx2], y=[cy2], color='g')
plt.title("X & Y Co-Ordinates | Centroid 1 & 2")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# Please input the number of elements required :
# 800
# Please input the max range :
# 1000
# Please enter centroid 1 co - ordinates
# Enter x co - ordinate
# 100
# Enter y co - ordinate
# 150
# Randomly Assigned Centroid1 : 100 150
# Please enter centroid 2 co - ordinates
# Enter x co - ordinate
# 850
# Enter y co - ordinate
# 900
# Randomly Assigned Centroid2 : 850 900

# %% [markdown]
# ### Initiate Stoping Criterion Design
# Create an empty list called termination !
# After each iteration is finished appened the that iterations centroids to the the mpty termination list.
#
# - Termination 1 | Create a for loop that moves one step forward if the current and previous element in the list are NOT equal !
# - Development 1 | Develop the correct area of input for this for loop.
#
# Basically the for loop will hold the entire program and break when termination 1 has been reached !

# %%
#Iniatite the empty list stopping criterion
Terminationx = []
Terminationy = []

# %% [markdown]
# # Iteration 1
# # Euclidean Distance Calculations (Step 1)
# This iteration will calculate the euclidean distance from the centroid and all the data points.
# We then proceed into inputting these calucalations and other into a pandas dataframe for easier interpretation and manipulation for the tasks that will follow.

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((cx1 - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((cy1 - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((cx2 - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((cy2 - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df = df.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df['EuclideanDistanceCalculationsCentroid1']:
    for f in df['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters.append(label1)
        if i <= f:
            Clusters.append(label2)
        break
                
#Append to Dataframe
df['ClusterLabels'] = Clusters
df
# Out:
#      Xco-ordinates  Yco-ordinates  EuclideanDistanceCalculationsCentroid1  \
# 0               24            962                              815.548895
# 1               69            853                              703.683167
# 2              610             92                              513.287444
# 3              178            567                              424.232248
# 4              673            916                              956.600753
# ..             ...            ...                                     ...
# 795            682            341                              612.539795
# 796            279             52                              204.071066
# 797            212            559                              424.057779
# 798            628            848                              875.207404
# 799            622            340                              555.503375
#
#      EuclideanDistanceCalculationsCentroid2 ClusterLabels
# ...

# %% [markdown]
# We can confirm the above task has been succesfully completed !
#
# # Re-Calculation Centroids (Step 2)
#
# The next task is to segragate the pandas dataframe based on the Cluster Labels (previously introduced using the euclidean distance calculation metric) into seperate pandas dataframe.
#
# We will then proceed to finding the centorids of these clusters !

# %% [markdown]
# ###### De- Bugging Step 2

# %%
#FINDING NEW CENTROIDS (ITERATIONS)
#isolate based on centroids

#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df.loc[df['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
# Out:
# Cluster 1 : 769.5285 4.74611

# %%
#Cluster 2
Cluster2 = df.loc[df['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

#print(Cluster2)
#print(CentroidCount2)
# Out:
# Cluster 2 : 400.28336 1.58484

# %% [markdown]
# ###### Step 2 De - Bugged

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df.loc[df['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df.loc[df['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break
# Out:
# Cluster 1 : 769.5285 4.74611
# Cluster 2 : 400.28336 1.58484

# %% [markdown]
# We can confirm we have succesfully calculated the new centroids for both specific clusters !
#
# NOTE
#
# An interesting appoach that we can implement which is a helpful attribute for this K Means Models is initiating a scatterplot that shows the newly assigned centroids and the invidiual data points which are color segragated shopwing which cluster they belong.
# From this we can compare the next iteration and re-asigning of the clusters and newly assigned centroids. This enables us to analyse and compare the iteration process !

# %% [markdown]
# # Iteration 2
# # Re - Calculation Euclidean Distance & Re - Calculation Centroids
# NOTE
#
# We will be utilising the original UNSEGRAGATED data points, to segragate into clusters based on the previous steps re-assigned centroids.
# Following this we will find new centroids within this clusters !
#
# Furthermore we could use the above mentioned approach but we will not as this notebook is primarily for de-bugging identification !

# %%
print('Cluster 1 | Iteration 1 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 1 :', new_centroid2x, new_centroid2y)
# Out:
# Cluster 1 | Iteration 1 : 769.5285 4.74611
# Cluster 2 | Iteration 1 : 400.28336 1.58484

# %% [markdown]
# These newly assigned centroids above which are from the previous iteration will now be passed into the metric calculator !

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df2 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df2 = df2.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters2 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df2['EuclideanDistanceCalculationsCentroid1']:
    for f in df2['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters2.append(label1)
        if i <= f:
            Clusters2.append(label2)
        break
                
#Append to Dataframe
df2['ClusterLabels'] = Clusters2
df2
# Out:
#      Xco-ordinates  Yco-ordinates  EuclideanDistanceCalculationsCentroid1  \
# 0               24            962                             1213.320961
# 1               69            853                             1100.124921
# 2              610             92                              181.831195
# 3              178            567                              816.109921
# 4              673            916                              916.352227
# ..             ...            ...                                     ...
# 795            682            341                              347.459230
# 796            279             52                              492.799289
# 797            212            559                              786.152277
# 798            628            848                              855.048209
# 799            622            340                              366.278349
#
#      EuclideanDistanceCalculationsCentroid2 ClusterLabels
# ...

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df2.loc[df2['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df2.loc[df2['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break
# Out:
# Cluster 1 : 121.5 17.17857
# Cluster 2 : 517.05242 0.12366

# %% [markdown]
# Analysing the centroids generated we can conclude these differ from the previous iterations generated centroids. There the threshold/termination criterion has not been reached.
#
# We will repeat the process !

# %% [markdown]
# # Iteration 3

# %%
print('Cluster 1 | Iteration 2 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 2 :', new_centroid2x, new_centroid2y)
# Out:
# Cluster 1 | Iteration 2 : 121.5 17.17857
# Cluster 2 | Iteration 2 : 517.05242 0.12366

# %% [markdown]
# We proceed to the next iteration as the centroids have not been altered !

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df3 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df3 = df3.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters3 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df3['EuclideanDistanceCalculationsCentroid1']:
    for f in df3['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters3.append(label1)
        if i <= f:
            Clusters3.append(label2)
        break
                
#Append to Dataframe
df3['ClusterLabels'] = Clusters3
df3

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df3.loc[df3['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df3.loc[df3['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

# %% [markdown]
# We proceed to the next iteration as the centroids have been altered from the previous iterations.

# %% [markdown]
# # Iteration 4

# %%
print('Cluster 1 | Iteration 3 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 3 :', new_centroid2x, new_centroid2y)

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df4 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df4 = df4.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters4 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df4['EuclideanDistanceCalculationsCentroid1']:
    for f in df4['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters4.append(label1)
        if i <= f:
            Clusters4.append(label2)
        break
                
#Append to Dataframe
df4['ClusterLabels'] = Clusters4
df4

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df4.loc[df4['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df4.loc[df4['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

# %% [markdown]
# We proceed to the next iteration as the stopping criterion has not been met !

# %% [markdown]
# # Iteration 5

# %%
print('Cluster 1 | Iteration 4 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 4 :', new_centroid2x, new_centroid2y)

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df5 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df5 = df5.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters5 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df5['EuclideanDistanceCalculationsCentroid1']:
    for f in df5['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters5.append(label1)
        if i <= f:
            Clusters5.append(label2)
        break
                
#Append to Dataframe
df5['ClusterLabels'] = Clusters5
df5

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df5.loc[df5['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df5.loc[df5['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

# %% [markdown]
# We proceed to the next iteration as the stopping criterion has not been met !

# %% [markdown]
# # Iteration 6

# %%
print('Cluster 1 | Iteration 5 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 5 :', new_centroid2x, new_centroid2y)

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df6 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df6 = df6.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters6 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df6['EuclideanDistanceCalculationsCentroid1']:
    for f in df6['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters6.append(label1)
        if i <= f:
            Clusters6.append(label2)
        break
                
#Append to Dataframe
df6['ClusterLabels'] = Clusters6
df6

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df6.loc[df6['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df6.loc[df6['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

# %% [markdown]
# # Iteration 7

# %%
print('Cluster 1 | Iteration 6 :', new_centroid1x, new_centroid1y)
print('Cluster 2 | Iteration 6 :', new_centroid2x, new_centroid2y)

# %%
#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
        
#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((new_centroid1x - xi) ** 2)
        #appending(adding calculations to list)
        break

for yi in Y:
    while len(Y) <= len(Y):
        list2.append((new_centroid1y - yi) ** 2)
        break
        
#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((new_centroid2x - xii) ** 2)
        break
        
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((new_centroid2y - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
                
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
        
#Transfering the above lists into a Dictionary
Dictionary = {'Xco-ordinates':X, 'Yco-ordinates':Y, 'EuclideanDistanceCalculationsCentroid1':list5, 
              'EuclideanDistanceCalculationsCentroid2':list6}
#Create a DataFrame from our above Dictionary
df7 = pd.DataFrame(Dictionary)
#Create copy of original dataframe
original_df7 = df7.copy(deep=True)
        
#Labelling the clusters for interpretability
Clusters7 = []
#Assign Labels for Centroid/Clusters
label1 = 'Centroid1'
label2 = 'Centroid2'
#initiate for loop to assign labels
#NOTE: These labels will represent which Cluster X & Y co-ordinates belong too !
for i in df7['EuclideanDistanceCalculationsCentroid1']:
    for f in df7['EuclideanDistanceCalculationsCentroid2']:
        if i > f:
            Clusters7.append(label1)
        if i <= f:
            Clusters7.append(label2)
        break
                
#Append to Dataframe
df7['ClusterLabels'] = Clusters7
df7

# %%
#CLUSTER 1
#Define the variable outside of the loop
Cluster1 = df7.loc[df7['ClusterLabels'] == 'Centroid1']
#count
CentroidCount1 = Cluster1['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx1 = 0
for x in Cluster1['Xco-ordinates']:
    sum_allx1 += x
    new_centroid1x = round(sum_allx1 / CentroidCount1,5)
#Adding all elements of Yco-ordinates
sum_ally1 = 0
for y in Cluster1['Yco-ordinates']:
    sum_ally1 += y
    new_centroid1y = round(sum_ally1 / CentroidCount1,5)
    print('Cluster 1 :', new_centroid1x, new_centroid1y)
    break
#Cluster 2
Cluster2 = df7.loc[df7['ClusterLabels'] == 'Centroid2']
#count
CentroidCount2 = Cluster2['ClusterLabels'].count()
#Adding all elements of Xco-ordinates
sum_allx2 = 0
for x in Cluster2['Xco-ordinates']:
    sum_allx2 += x
    new_centroid2x = round(sum_allx2 / CentroidCount2,5)
#Adding all elements of Yco-ordinates
sum_ally2 = 0
for y in Cluster2['Yco-ordinates']:
    sum_ally2 += y
    new_centroid2y = round(sum_ally2 / CentroidCount2,5)
    print('Cluster 2 :', new_centroid2x, new_centroid2y)
    break

# %% [markdown]
# ### Scatterplot Analysis

# %%
#scatterplot
#x & y co-ordniates
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.scatter(data = Cluster1, x = 'Xco-ordinates', y = 'Yco-ordinates', color = 'b')
ax.scatter(data = Cluster2, x = 'Xco-ordinates', y = 'Yco-ordinates', color = 'r')
# append new centroids 
plt.scatter(x=new_centroid1x, y=new_centroid1y, color='r')
plt.scatter(x=new_centroid2x, y=new_centroid2y, color='b')
plt.title("CLUSTERS")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ###### Plausible Bugs Identified
#
# BUG One
#
# The termination threshold appears within Iteration 5 & Iteration 7, as centroids are equal. However, at this point we are unsure of iteration 6's nature, as it is between both iteration 5 & iteration 6 which could possibly signify a bug in the calculations or code ! This need to be investigated.
#
# BUG Two
#
# Analysing via scatterplot we can confirm that based on the color segragting & identifying clusters it appears like evenly divided clusters. However this is an assumption as at this point we are unsure of how this model actually generates the succesful completion of the clusters.
#
# Both these plausible bugs identified require further investigation. What is required is an approach that will help identify and de-bug ann bugs in the calculations or code !
#
# ###### APPROACH
#
# Manually test data and compare the results by inputting the same test data into the model. This will help detect bugs and confirm model accuracy
