# %% [markdown]
# ### Euclidean Distance
#
#                EUCLIDEAN DISTANCE FORMULA: d([x1,y1],[x2,y2]) => sqrt((x1 - x2)**2 + (y1-y2)**2)
#
# Task
#
# Build a program that calculates the euclidean distance from a given number of elements USING TWO centroids.
#
# Included:
#
# - User-Interface program for completing the euclidean distance calculations
# This enables users to interact with the program.
# However a key takeaway from this project for other python enthusiasts & coders should be not the mathematics involved within the euclidean distance but more so an in depth look at collection type properties and distinguishing whoch is the best fit for the tasks within this program.
#
# - De - Bugging
# This approach involved breaking down the code into small segements for both detetcing bugs and solving tasks required to build this program.
#
# Project Information
#
# This program was designed as a subtask of an ongoing project which is the development of the unsupervised K - Means Clustering Algorithim.
#
# This sub task (Euclidean Distance Project) enables python enthusiasts to get into the internal working of lists and insight into other data collection types.
#
# When choosing a collection type as in the case for this project, it is useful to understand the properties of that collection type/s. The rationale for this it will enable problem solving, efficiency and succesful completing of the desired objectives and goals.
#
# It must be noted a method of trial and error was the blue-print utilized in attempts to find the best collection types for such tasks required to complete this program.
#
# Issue's/Key Learning
#
# A key takeaway from this project is that when CONVERTING lists into dictionaries, repeated keys will be removed automatically. This posed an issue moving forward with the mathematical calculations in the specific sequence required in the concluding sections of the program. The solution was initiating a for loop and zipping lists together whilst iterating throughout the elements within the lists and performing calculation required (see line 80).

# %%
#import required libraries
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from math import sqrt

# %% [markdown]
# ##### User-Interface Program | Euclidean DIstance
# INSTRUCTIONS
#
# - Enter the number of elements you wish to caculate the euclidean distace for !
# - Enter two centroid x & y co ordinates to compute the euclidean distance from the given elements.
# - Read & Follow the below instructions

# %%
print('Please input number of elements :')
n1 = input()
#convert string to integer rationale range function & randinint requires interger value
n1 = int(n1)
print('Please input the max range :')
n2 = input()
n2 = int(n2)

#create two random lists to hold X & Y co - ordinates of elements
#X co-ordinates
X = []
#Y co - ordinates
Y = []

#intialize for loop with the range function (start/end)
for i in range(0,n1):
    #Generates a random number between a given positive range
    x = random.randint(1,n2)
    #appends to empty list(adds)
    X.append(x)
for i in range(0,n1):
    y = random.randint(1,n2)
    Y.append(y)


print('Please enter centroid 1 co - ordinates')
print('Enter x co - ordinate')
cx1 = input()
cx1 = int(cx1)
print('Enter y co - ordinate')
cy1 = input()
cy1 = int(cy1)
print('Centroid 1 x co - ordinates:',cx1)
print('Centroid 1 y co - ordinates:',cy1)

print('Please enter centroid 2 co - ordinates')
print('Enter x co - ordinate')
cx2 = input()
cx2 = int(cx2)
print('Enter y co - ordinate')
cy2 = input()
cy2 = int(cy2)
print('Centroid 2 x co - ordinates:',cx2)
print('Centroid 2 y co - ordinates:',cy2)

#SCATTERPLOT 
#x & y co-ordniates
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.scatter(X, Y)
# add centroid 1 & centroid 2
plt.scatter(x=[cx1], y=[cy1], color='b')
plt.scatter(x=[cx2], y=[cy2], color='g')
plt.title("X & Y Co-Ordinates | Centroid 1 & 2")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()


#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []

#eulcidean distance calculations
for xi in X:
    #while loop : terminate the for loop when length of list1 exceeds the length of the list2
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list1.append((cx1 - xi) ** 2)
        #appending(adding calculations to list)
        break
for yi in Y:
    while len(Y) <= len(Y):
        list2.append((cy1 - yi) ** 2)
        break

#for loop to loop over list
for xii in X:
    while len(X) <= len(X):
        list3.append((cx2 - xii) ** 2)
        break
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((cy2 - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
        
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break
    
print('Euclidean Distance Calculations:',list5)
#print(type(list5))
print('Eulclidean Distance Calculations:',list6)
#print(type(list6))
# Out:
# Please input number of elements :
# 30
# Please input the max range :
# 34
# Please enter centroid 1 co - ordinates
# Enter x co - ordinate
# 12
# Enter y co - ordinate
# 23
# Centroid 1 x co - ordinates: 12
# Centroid 1 y co - ordinates: 23
# Please enter centroid 2 co - ordinates
# Enter x co - ordinate
# 45
# Enter y co - ordinate
# 12
# Centroid 2 x co - ordinates: 45
# Centroid 2 y co - ordinates: 12
# ...

# %% [markdown]
# ### De - Bugging Identification
# Calculations including all the specified values have been externally & manually checked confirming the programs 100% accuracy calculating the euclidean distance from the two specified centroids.
#
# This approach along with breaking the computations into small segements prooved usefull in detecting bugs and providing solutions.

# %%
#create x/y co - ordinates (data points)
X = [1,3,4,5,1,4]
Y = [3,3,3,3,2,2]

#centroid 1 co-ordinates
cx1 = 1
cy1 = 1
#centorid 2 co-ordinates
cx2 = 2
cy2 = 1

#initiliaze empty lists
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []

#eulcidean distance calculations
for xi in X:
    while len(X) <= len(X):
        list1.append((cx1 - xi) ** 2)
        break
for yi in Y:
    while len(Y) <= len(Y):
        list2.append((cy1 - yi) ** 2)
        break
        
##eulcidean distance calculations continued

#for loop to loop over list
for xii in X:
    #while loop : expression
    while len(X) <= len(X):
        #appending(adding calculations to list)
        list3.append((cx2 - xii) ** 2)
        #break out of the while loop
        break
for yii in Y:
    while len(Y) <= len(Y):
        list4.append((cy2 - yii) ** 2)
        break
        
#for loop zipping together two lists   
for x,y in zip (list1,list2):
    while len(list1) <= len(list2):
        #square root calculations
        phase1 = sqrt(x + y)
        list5.append(phase1)
        break
        
for a,b in zip (list3,list4):
    while len(list3) <= len(list4):
        phase2 = sqrt(a + b)
        list6.append(phase2)
        break

print(X,Y)
print('Euclidean Distance Calculations:',list5)
#print(type(list5))
print('Eulclidean Distance Calculations:',list6)
#print(type(list6))
# Out:
# [1, 3, 4, 5, 1, 4] [3, 3, 3, 3, 2, 2]
# Euclidean Distance Calculations: [2.0, 2.8284271247461903, 3.605551275463989, 4.47213595499958, 1.0, 3.1622776601683795]
# Eulclidean Distance Calculations: [2.23606797749979, 2.23606797749979, 2.8284271247461903, 3.605551275463989, 1.4142135623730951, 2.23606797749979]
